# %% [markdown]
# ### CNN TIME

# %%
import preprocessor.time_preprocessor as preprocessor
X_train, y_train, X_val, y_val, X_test, y_test = preprocessor.preprocess(True, True, True)

# %%
print(X_train.shape)
# Out:
# (2880, 18, 1280)

# %% [markdown]
# Load CNN model

# %%
from ia.cnn.time_cnn import TimeCNN
time_cnn = TimeCNN(input_shape=(X_train[0].shape))

# %%
time_cnn.compile()

# %%
NR_EPOCHS = 100
BATCH_SIZE = 250

# %%
time_cnn.fit(X_train, y_train, num_epochs=NR_EPOCHS, batch_size=BATCH_SIZE, val_data=X_val, val_labels=y_val)

# %%
time_cnn.plot_train_val()

# %%
time_cnn.predict(X_test)
time_cnn.print_predictions(y_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [ True] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [ True] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [ True] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [ True] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [False] | REAL: False
# PREDICTION: [ True] | REAL: True
# PREDICTION: [False] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [False] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [False] | REAL: True
# PREDICTION: [False] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [False] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [False] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [False] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [False] | REAL: True
# PREDICTION: [False] | REAL: True
# PREDICTION: [False] | REAL: True
# PREDICTION: [False] | REAL: True
# PREDICTION: [False] | REAL: True
# PREDICTION: [False] | REAL: True
# PREDICTION: [False] | REAL: True
# PREDICTION: [False] | REAL: True
# PREDICTION: [False] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [False] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [False] | REAL: True
# PREDICTION: [False] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [ True] | REAL: True
# PREDICTION: [False] | REAL: True

# %% [markdown]
# ### METRICS:

# %%
from metrics.metrics import Metrics
metrics = Metrics(y_test, time_cnn.predictions, time_cnn.name(), "time")
metrics.all_metrics()
metrics.metrics_to_database()
# Out:
# True Positives: 31
# True Negatives: 47
# False Positives: 20
# False Negatives: 4
# total Samples: 102
# Accuracy: 0.7647058823529411
# Precision: 0.6078431372549019
# Sensitivity: 0.8857142857142857
# Specificity: 0.7014925373134329
# TPR: 0.6078431372549019
# FPR: 0.29850746268656714
# F1-Score: 0.8207739307535641

# %% [markdown]
# ROC curve

# %%
metrics.plot_roc_auc(y_test, time_cnn.predictions)
