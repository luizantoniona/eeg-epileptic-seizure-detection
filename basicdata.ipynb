# %% [markdown]
# # Basic Data:
# Notebook para gerar informações básicas utilizada na dissertação

# %% [markdown]
# ### Banda de ondas classificadas no EEG

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

time = np.arange(0, 2, 0.001)

delta_waves = np.sin(0.3*2*np.pi*time) + np.sin(1*2*np.pi*time) + np.sin(4*2*np.pi*time)
theta_waves = np.sin(4.5*2*np.pi*time) + np.sin(6*2*np.pi*time) + np.sin(8*2*np.pi*time)
alpha_waves = np.sin(8.5*2*np.pi*time) + np.sin(10*2*np.pi*time) + np.sin(13*2*np.pi*time)
beta_waves = np.sin(14*2*np.pi*time) + np.sin(20*2*np.pi*time) + np.sin(25*2*np.pi*time) + np.sin(30*2*np.pi*time)
lowgamma_waves = np.sin(31*2*np.pi*time) + np.sin(40*2*np.pi*time) + np.sin(45*2*np.pi*time) + np.sin(50*2*np.pi*time) + np.sin(80*2*np.pi*time)
highgamma_waves = np.sin(80.5*2*np.pi*time) + np.sin(90*2*np.pi*time) + np.sin(100*2*np.pi*time) + np.sin(125*2*np.pi*time) + np.sin(150*2*np.pi*time)

figure = plt.figure(figsize=(20,20))

deltax = figure.add_subplot(611)
deltax.set_title('Delta Waves')
deltax.set_xlim(left=0, right=2)
deltax.xaxis.set_major_locator(ticker.NullLocator())
deltax.yaxis.set_major_locator(ticker.NullLocator())
deltax.plot(time, delta_waves)

thetax = figure.add_subplot(612)
thetax.set_title('Theta Waves')
thetax.set_xlim(left=0, right=2)
thetax.xaxis.set_major_locator(ticker.NullLocator())
thetax.yaxis.set_major_locator(ticker.NullLocator())
thetax.plot(time, theta_waves)

alphax = figure.add_subplot(613)
alphax.set_title('Alpha Waves')
alphax.set_xlim(left=0, right=2)
alphax.xaxis.set_major_locator(ticker.NullLocator())
alphax.yaxis.set_major_locator(ticker.NullLocator())
alphax.plot(time, alpha_waves)

betax = figure.add_subplot(614)
betax.set_title('Beta Waves')
betax.set_xlim(left=0, right=2)
betax.xaxis.set_major_locator(ticker.NullLocator())
betax.yaxis.set_major_locator(ticker.NullLocator())
betax.plot(time, beta_waves)

lowgammax = figure.add_subplot(615)
lowgammax.set_title('Low Gamma Waves')
lowgammax.xaxis.set_major_locator(ticker.NullLocator())
lowgammax.yaxis.set_major_locator(ticker.NullLocator())
lowgammax.set_xlim(left=0, right=2)
lowgammax.plot(time, lowgamma_waves)

highgammax = figure.add_subplot(616)
highgammax.set_title('High Gamma Waves')
highgammax.xaxis.set_major_locator(ticker.NullLocator())
highgammax.yaxis.set_major_locator(ticker.NullLocator())
highgammax.set_xlim(left=0, right=2)
highgammax.plot(time, highgamma_waves)

plt.show();

# %% [markdown]
# ### Transformação domínio do tempo para frequência

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

N = 5000
T = 1.0 / 100.0
time = np.linspace(0.0, N*T, N)
frequency = np.linspace(0.0, 1.0/(2.0*T), N//2)

##Frequencies: 0.3Hz && 1Hz && 4Hz
temporal_wave = np.sin(0.3*2*np.pi*time) + 2*np.sin(2*np.pi*time) + np.sin(8*np.pi*time)
frequency_wave = np.fft.fft(temporal_wave)

figure = plt.figure(figsize=(5,5))

temporalx = figure.add_subplot(211)
temporalx.set_title('Temporal Waves')
temporalx.set_xlim(left=0, right=2)
temporalx.xaxis.set_major_locator(ticker.NullLocator())
temporalx.yaxis.set_major_locator(ticker.NullLocator())
temporalx.plot(time, temporal_wave)

frequencyx = figure.add_subplot(212)
frequencyx.set_title('Frequency Bands')
frequencyx.set_xlim(left=0, right=6)
frequencyx.xaxis.set_major_locator(ticker.NullLocator())
frequencyx.yaxis.set_major_locator(ticker.NullLocator())
frequencyx.plot(frequency, 2.0/N*np.abs(frequency_wave[:N//2]) )

# %% [markdown]
# ### Todas as bandas e o seu fft

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

N = 50000
T = 1.0 / 500.0
time = np.linspace(0.0, N*T, N)
frequency = np.linspace(0.0, 1.0/(2.0*T), N//2)

delta_waves = np.sin(0.3*2*np.pi*time) + np.sin(1*2*np.pi*time) + np.sin(4*2*np.pi*time)
theta_waves = np.sin(4.5*2*np.pi*time) + np.sin(6*2*np.pi*time) + np.sin(8*2*np.pi*time)
alpha_waves = np.sin(8.5*2*np.pi*time) + np.sin(10*2*np.pi*time) + np.sin(13*2*np.pi*time)
beta_waves = np.sin(14*2*np.pi*time) + np.sin(20*2*np.pi*time) + np.sin(25*2*np.pi*time) + np.sin(30*2*np.pi*time)
lowgamma_waves = np.sin(31*2*np.pi*time) + np.sin(40*2*np.pi*time) + np.sin(45*2*np.pi*time) + np.sin(50*2*np.pi*time) + np.sin(80*2*np.pi*time)
highgamma_waves = np.sin(80.5*2*np.pi*time) + np.sin(90*2*np.pi*time) + np.sin(100*2*np.pi*time) + np.sin(125*2*np.pi*time) + np.sin(150*2*np.pi*time)

temporal_wave = delta_waves + theta_waves + alpha_waves + beta_waves + lowgamma_waves + highgamma_waves
frequency_wave = np.fft.fft(temporal_wave)

figure = plt.figure(figsize=(15,5))

temporalx = figure.add_subplot(211)
temporalx.set_title('Temporal Waves')
temporalx.set_xlim(left=0, right=2)
temporalx.xaxis.set_major_locator(ticker.NullLocator())
temporalx.yaxis.set_major_locator(ticker.NullLocator())
temporalx.plot(time, temporal_wave)

frequencyx = figure.add_subplot(212)
frequencyx.set_title('Frequency Bands')
frequencyx.set_xlim(left=0, right=150)
#frequencyx.xaxis.set_major_locator(ticker.NullLocator())
frequencyx.yaxis.set_major_locator(ticker.NullLocator())
frequencyx.plot(frequency, 2.0/N*np.abs(frequency_wave[:N//2])**2 )

# %% [markdown]
# ### TFT e PSD

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.mlab as mlab

N = 50000
T = 1.0 / 500.0
time = np.linspace(0.0, N*T, N)
frequency = np.linspace(0.0, 1.0/(2.0*T), N//2)

delta_waves = np.sin(0.3*2*np.pi*time) + np.sin(1*2*np.pi*time) + np.sin(4*2*np.pi*time)
theta_waves = np.sin(4.5*2*np.pi*time) + np.sin(6*2*np.pi*time) + np.sin(8*2*np.pi*time)
alpha_waves = np.sin(8.5*2*np.pi*time) + np.sin(10*2*np.pi*time) + np.sin(13*2*np.pi*time)
beta_waves = np.sin(14*2*np.pi*time) + np.sin(20*2*np.pi*time) + np.sin(25*2*np.pi*time) + np.sin(30*2*np.pi*time)
lowgamma_waves = np.sin(31*2*np.pi*time) + np.sin(40*2*np.pi*time) + np.sin(45*2*np.pi*time) + np.sin(50*2*np.pi*time) + np.sin(80*2*np.pi*time)
highgamma_waves = np.sin(80.5*2*np.pi*time) + np.sin(90*2*np.pi*time) + np.sin(100*2*np.pi*time) + np.sin(125*2*np.pi*time) + np.sin(150*2*np.pi*time)

temporal_wave = delta_waves + theta_waves - alpha_waves + beta_waves + lowgamma_waves + highgamma_waves
frequency_wave = np.fft.fft(temporal_wave)

figure = plt.figure(figsize=(15,10))

temporalx = figure.add_subplot(311)
temporalx.set_title('Temporal Waves')
temporalx.set_xlim(left=0, right=2)
temporalx.xaxis.set_major_locator(ticker.NullLocator())
temporalx.yaxis.set_major_locator(ticker.NullLocator())
temporalx.plot(time, temporal_wave)

frequencyx = figure.add_subplot(312)
frequencyx.set_title('Frequency Bands')
frequencyx.set_xlim(left=0, right=150)
frequencyx.xaxis.set_major_locator(ticker.NullLocator())
frequencyx.yaxis.set_major_locator(ticker.NullLocator())
frequencyx.plot( frequency, 2.0/N*np.abs(frequency_wave[:N//2])**2 )

psdx = figure.add_subplot(313)
psdx.set_title("Power Spectrum")
psdx.set_xlim(left=0, right=150)
#psdx.xaxis.set_major_locator(ticker.NullLocator())
#psdx.yaxis.set_major_locator(ticker.NullLocator())
psdx.psd(temporal_wave, Fs=1000, window=mlab.window_none, pad_to=512)
# Out:
# (array([1.69377135e-01, 2.52488869e-01, 7.60364507e-02, 6.92664424e-02,
#         2.33787011e-01, 2.26695988e-01, 1.56686704e-01, 1.24705148e-01,
#         2.20323862e-01, 2.30353353e-01, 1.54700121e-01, 9.86039444e-02,
#         3.49664565e-02, 1.53126804e-01, 2.07746695e-01, 9.84511973e-02,
#         1.42812667e-02, 1.28679179e-02, 9.10924671e-03, 1.84529907e-02,
#         1.09136466e-01, 1.07738565e-01, 1.46087641e-02, 1.29562470e-02,
#         1.18644365e-02, 1.00902695e-01, 1.14751517e-01, 2.13303910e-02,
#         1.06984182e-02, 1.33869009e-02, 8.62958903e-02, 2.01791108e-01,
#         1.49046131e-01, 3.16016152e-02, 7.61625693e-03, 6.36951165e-03,
#         4.95215367e-03, 3.57196106e-03, 7.71464643e-03, 3.05324386e-03,
#         5.73105148e-02, 1.31487576e-01, 4.94820959e-02, 6.88204336e-03,
#         7.43887798e-03, 4.55517431e-02, 1.31977212e-01, 6.06363926e-02,
#         6.31558313e-03, 7.49871153e-03, 3.35113436e-02, 1.26476266e-01,
#         7.44998369e-02, 3.15849774e-03, 6.74269264e-03, 1.54189044e-03,
#         2.66285134e-03, 1.13926109e-03, 1.55785210e-03, 9.66143815e-04,
#         1.09222843e-03, 8.85520950e-04, 8.49644423e-04, 8.58582589e-04,
#         7.08690283e-04, 8.73409750e-04, 6.24006898e-04, 9.30872931e-04,
#         5.77002708e-04, 1.04327930e-03, 5.61912919e-04, 1.24098414e-03,
#         5.83203974e-04, 1.59436866e-03, 6.61667766e-04, 2.28641608e-03,
#         8.62637289e-04, 3.91869424e-03, 1.43536078e-03, 9.58450518e-03,
#         4.04087591e-03, 7.70452136e-02, 2.36722940e-01, 1.41180581e-01,
#         8.81674997e-03, 1.11109473e-02, 1.99366067e-03, 5.50236387e-03,
#         1.14067280e-03, 6.91179236e-03, 1.37077548e-03, 3.74636922e-02,
#         1.25884693e-01, 7.04383174e-02, 1.56137615e-03, 7.36759972e-03,
#         9.64200720e-04, 3.87372884e-03, 1.32247404e-03, 4.60062916e-03,
#         3.52421017e-03, 1.86898354e-02, 1.12952628e-01, 9.41909342e-02,
#         7.03935328e-03, 5.40499491e-03, 1.46125918e-03, 2.03201290e-03,
#         6.63703448e-04, 1.21461668e-03, 4.06370512e-04, 9.08893960e-04,
#         2.90949782e-04, 7.85722625e-04, 2.28779175e-04, 7.61482845e-04,
#         1.91182461e-04, 8.21747771e-04, 1.66627819e-04, 9.96678178e-04,
#         1.49765438e-04, 1.39761323e-03, 1.37861737e-04, 2.41840898e-03,
#         1.29442337e-04, 6.15243583e-03, 1.23793136e-04, 5.23478578e-02,
#         1.28118879e-01, 5.18166219e-02, 1.18694868e-04, 5.79843515e-03,
#         1.19200217e-04, 2.17443921e-03, 1.22392393e-04, 1.19504508e-03,
#         1.28940485e-04, 8.09163830e-04, 1.40273276e-04, 6.35595727e-04,
#         1.59077761e-04, 5.67605239e-04, 1.90657188e-04, 5.76716875e-04,
#         2.46495069e-04, 6.77842103e-04, 3.55184275e-04, 9.55157101e-04,
#         6.04972948e-04, 1.74217407e-03, 1.39032422e-03, 5.11491020e-03,
#         6.86717891e-03, 9.37677823e-02, 1.12605410e-01, 1.78159398e-02,
#         3.18362105e-03, 3.14920030e-03, 9.96337132e-04, 1.32578554e-03,
#         5.04046558e-04, 7.57684430e-04, 3.17074064e-04, 5.06914648e-04,
#         2.26012984e-04, 3.73095959e-04, 1.74582905e-04, 2.92538404e-04,
#         1.42506645e-04, 2.39814976e-04, 1.21019156e-04, 2.03124496e-04,
#         1.05824782e-04, 1.76366154e-04, 9.46146298e-05, 1.56118540e-04,
#         8.60563734e-05, 1.40336444e-04, 7.93365774e-05, 1.27732747e-04,
#         7.39352287e-05, 1.17462332e-04, 6.95069207e-05, 1.08950202e-04,
#         6.58146716e-05, 1.01793123e-04, 6.26913076e-05, 9.57008470e-05,
#         6.00160193e-05, 9.04596658e-05, 5.76996362e-05, 8.59090674e-05,
#         5.56750974e-05, 8.19263588e-05, 5.38911216e-05, 7.84162794e-05,
#         5.23079038e-05, 7.53038282e-05, 5.08941277e-05, 7.25292106e-05,
#         4.96248528e-05, 7.00442137e-05, 4.84799954e-05, 6.78095645e-05,
#         4.74432182e-05, 6.57929743e-05, 4.65011085e-05, 6.39676733e-05,
#         4.56425614e-05, 6.23112970e-05, 4.48583118e-05, 6.08050317e-05,
#         4.41405749e-05, 5.94329511e-05, 4.34827677e-05, 5.81814962e-05,
#         4.28792913e-05, 5.70390652e-05, 4.23253585e-05, 5.59956853e-05,
#         4.18168573e-05, 5.50427498e-05, 4.13502411e-05, 5.41728057e-05,
#         4.09224403e-05, 5.33793803e-05, 4.05307904e-05, 5.26568394e-05,
#         4.01729730e-05, 5.20002711e-05, 3.98469684e-05, 5.14053886e-05,
#         3.95510150e-05, 5.08684509e-05, 3.92835771e-05, 5.03861959e-05,
#         3.90433175e-05, 4.99557849e-05, 3.88290744e-05, 4.95747560e-05,
#         3.86398431e-05, 4.92409854e-05, 3.84747599e-05, 4.89526554e-05,
#         3.83330895e-05, 4.87082271e-05, 3.82142137e-05, 4.85064189e-05,
#         3.81176232e-05, 4.83461881e-05, 3.80429102e-05, 4.82267167e-05,
#         3.79897629e-05, 4.81474007e-05, 3.79579617e-05, 4.81078416e-05,
#         1.89736879e-05]),
#  array([  0.      ,   1.953125,   3.90625 ,   5.859375,   7.8125  ,
#           9.765625,  11.71875 ,  13.671875,  15.625   ,  17.578125,
#          19.53125 ,  21.484375,  23.4375  ,  25.390625,  27.34375 ,
#          29.296875,  31.25    ,  33.203125,  35.15625 ,  37.109375,
#          39.0625  ,  41.015625,  42.96875 ,  44.921875,  46.875   ,
#          48.828125,  50.78125 ,  52.734375,  54.6875  ,  56.640625,
#          58.59375 ,  60.546875,  62.5     ,  64.453125,  66.40625 ,
#          68.359375,  70.3125  ,  72.265625,  74.21875 ,  76.171875,
#          78.125   ,  80.078125,  82.03125 ,  83.984375,  85.9375  ,
#          87.890625,  89.84375 ,  91.796875,  93.75    ,  95.703125,
#          97.65625 ,  99.609375, 101.5625  , 103.515625, 105.46875 ,
#         107.421875, 109.375   , 111.328125, 113.28125 , 115.234375,
#         117.1875  , 119.140625, 121.09375 , 123.046875, 125.      ,
#         126.953125, 128.90625 , 130.859375, 132.8125  , 134.765625,
#         136.71875 , 138.671875, 140.625   , 142.578125, 144.53125 ,
#         146.484375, 148.4375  , 150.390625, 152.34375 , 154.296875,
#         156.25    , 158.203125, 160.15625 , 162.109375, 164.0625  ,
#         166.015625, 167.96875 , 169.921875, 171.875   , 173.828125,
#         175.78125 , 177.734375, 179.6875  , 181.640625, 183.59375 ,
#         185.546875, 187.5     , 189.453125, 191.40625 , 193.359375,
#         195.3125  , 197.265625, 199.21875 , 201.171875, 203.125   ,
#         205.078125, 207.03125 , 208.984375, 210.9375  , 212.890625,
#         214.84375 , 216.796875, 218.75    , 220.703125, 222.65625 ,
#         224.609375, 226.5625  , 228.515625, 230.46875 , 232.421875,
#         234.375   , 236.328125, 238.28125 , 240.234375, 242.1875  ,
#         244.140625, 246.09375 , 248.046875, 250.      , 251.953125,
#         253.90625 , 255.859375, 257.8125  , 259.765625, 261.71875 ,
#         263.671875, 265.625   , 267.578125, 269.53125 , 271.484375,
#         273.4375  , 275.390625, 277.34375 , 279.296875, 281.25    ,
#         283.203125, 285.15625 , 287.109375, 289.0625  , 291.015625,
#         292.96875 , 294.921875, 296.875   , 298.828125, 300.78125 ,
#         302.734375, 304.6875  , 306.640625, 308.59375 , 310.546875,
#         312.5     , 314.453125, 316.40625 , 318.359375, 320.3125  ,
#         322.265625, 324.21875 , 326.171875, 328.125   , 330.078125,
#         332.03125 , 333.984375, 335.9375  , 337.890625, 339.84375 ,
#         341.796875, 343.75    , 345.703125, 347.65625 , 349.609375,
#         351.5625  , 353.515625, 355.46875 , 357.421875, 359.375   ,
#         361.328125, 363.28125 , 365.234375, 367.1875  , 369.140625,
#         371.09375 , 373.046875, 375.      , 376.953125, 378.90625 ,
#         380.859375, 382.8125  , 384.765625, 386.71875 , 388.671875,
#         390.625   , 392.578125, 394.53125 , 396.484375, 398.4375  ,
#         400.390625, 402.34375 , 404.296875, 406.25    , 408.203125,
#         410.15625 , 412.109375, 414.0625  , 416.015625, 417.96875 ,
#         419.921875, 421.875   , 423.828125, 425.78125 , 427.734375,
#         429.6875  , 431.640625, 433.59375 , 435.546875, 437.5     ,
#         439.453125, 441.40625 , 443.359375, 445.3125  , 447.265625,
#         449.21875 , 451.171875, 453.125   , 455.078125, 457.03125 ,
#         458.984375, 460.9375  , 462.890625, 464.84375 , 466.796875,
#         468.75    , 470.703125, 472.65625 , 474.609375, 476.5625  ,
#         478.515625, 480.46875 , 482.421875, 484.375   , 486.328125,
#         488.28125 , 490.234375, 492.1875  , 494.140625, 496.09375 ,
#         498.046875, 500.      ]))

# %% [markdown]
# ### Spectograma

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

N = 50000
T = 1.0 / 500.0
time = np.linspace(0.0, N*T, N)
frequency = np.linspace(0.0, 1.0/(2.0*T), N//2)

delta_waves = np.sin(0.3*2*np.pi*time) + np.sin(1*2*np.pi*time) + np.sin(4*2*np.pi*time)
theta_waves = np.sin(4.5*2*np.pi*time) + np.sin(6*2*np.pi*time) + np.sin(8*2*np.pi*time)
alpha_waves = np.sin(8.5*2*np.pi*time) + np.sin(10*2*np.pi*time) + np.sin(13*2*np.pi*time)
beta_waves = np.sin(14*2*np.pi*time) + np.sin(20*2*np.pi*time) + np.sin(25*2*np.pi*time) + np.sin(30*2*np.pi*time)
lowgamma_waves = np.sin(31*2*np.pi*time) + np.sin(40*2*np.pi*time) + np.sin(45*2*np.pi*time) + np.sin(50*2*np.pi*time) + np.sin(80*2*np.pi*time)
highgamma_waves = np.sin(80.5*2*np.pi*time) + np.sin(90*2*np.pi*time) + np.sin(100*2*np.pi*time) + np.sin(125*2*np.pi*time) + np.sin(150*2*np.pi*time)

temporal_wave = delta_waves + theta_waves - alpha_waves + beta_waves + lowgamma_waves + highgamma_waves

figure = plt.figure(figsize=(10,10))

plt.specgram(temporal_wave)
plt.show()
