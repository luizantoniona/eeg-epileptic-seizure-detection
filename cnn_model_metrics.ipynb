# %% [markdown]
# ### Model Metrics

# %%
from database.database_metrics import DatabaseMetrics
from metrics.metrics_model import MetricsModel
import metrics.metrics_converter as converter

MODEL = "time_cnn"
DOMAIN = "time"

database = DatabaseMetrics()
db_objects = database.metrics_by_model_and_domain(MODEL, DOMAIN)

time_metrics = []

for db_object in db_objects:
    time_metrics.append(converter.model_from_tuple(db_object))

true_positives = []
true_negatives = []
false_positives = []
false_negatives = []
total_samples = []
accuracy = []
precision = []
sensitivity = []
specificity = []
true_positive_rate = []
false_positive_rate = []
f1_score = []

for time_metric in time_metrics:
    true_positives.append( time_metric.true_positives )
    true_negatives.append( time_metric.true_negatives )
    false_positives.append( time_metric.false_positives )
    false_negatives.append( time_metric.false_negatives )
    total_samples.append( time_metric.total_samples )
    accuracy.append( time_metric.accuracy )
    precision.append( time_metric.precision )
    sensitivity.append( time_metric.sensitivity )
    specificity.append( time_metric.specificity )
    true_positive_rate.append( time_metric.true_positive_rate )
    false_positive_rate.append( time_metric.false_positive_rate )
    f1_score.append( time_metric.f1_score )

final_time_metrics = MetricsModel(MODEL, DOMAIN,
                                  true_positives,
                                  true_negatives,
                                  false_positives,
                                  false_negatives,
                                  total_samples,
                                  accuracy,
                                  precision,
                                  sensitivity,
                                  specificity,
                                  true_positive_rate,
                                  false_positive_rate,
                                  f1_score)

final_time_metrics.show_name()
final_time_metrics.show_mean()
final_time_metrics.show_deviation()
# Out:
# MODEL: time_cnn
# DATA DOMAIN: time
# ------------------------------------
# True Positives: 43.9
# True Negatives: 87.4
# False Positives: 21
# False Negatives: 21.6
# Total Samples: 173.9
# ------------------------------------
# MEAN:
# Accuracy: 0.7337716
# Precision: 0.6845168
# Sensitivity: 0.6670743
# Specificity: 0.7951223
# TPR: 0.6845168
# FPR: 0.2048777
# F1-Score: 0.6964451
# ------------------------------------
# DEVIATION:
# Accuracy: 0.05484485063194175
# Precision: 0.0807277777481828
# Sensitivity: 0.1223743074661099
# Specificity: 0.04009145570579849
# TPR: 0.0807277777481828
# FPR: 0.04009145570579845
# F1-Score: 0.09046677373981013
# ------------------------------------

# %%
from database.database_metrics import DatabaseMetrics
from metrics.metrics_model import MetricsModel
import metrics.metrics_converter as converter

MODEL = "frequency_cnn"
DOMAIN = "frequency"

database = DatabaseMetrics()
db_objects = database.metrics_by_model_and_domain(MODEL, DOMAIN)

frequency_metrics = []

for db_object in db_objects:
    frequency_metrics.append(converter.model_from_tuple(db_object))

true_positives = []
true_negatives = []
false_positives = []
false_negatives = []
total_samples = []
accuracy = []
precision = []
sensitivity = []
specificity = []
true_positive_rate = []
false_positive_rate = []
f1_score = []


for frequency_metric in frequency_metrics:
    true_positives.append( frequency_metric.true_positives )
    true_negatives.append( frequency_metric.true_negatives )
    false_positives.append( frequency_metric.false_positives )
    false_negatives.append( frequency_metric.false_negatives )
    total_samples.append( frequency_metric.total_samples )
    accuracy.append( frequency_metric.accuracy )
    precision.append( frequency_metric.precision )
    sensitivity.append( frequency_metric.sensitivity )
    specificity.append( frequency_metric.specificity )
    true_positive_rate.append( frequency_metric.true_positive_rate )
    false_positive_rate.append( frequency_metric.false_positive_rate )
    f1_score.append( frequency_metric.f1_score )

final_frequency_metrics = MetricsModel( MODEL, DOMAIN,
                                        true_positives,
                                        true_negatives,
                                        false_positives,
                                        false_negatives,
                                        total_samples,
                                        accuracy,
                                        precision,
                                        sensitivity,
                                        specificity,
                                        true_positive_rate,
                                        false_positive_rate,
                                        f1_score)

final_frequency_metrics.show_name()
final_frequency_metrics.show_mean()
final_frequency_metrics.show_deviation()
# Out:
# MODEL: frequency_cnn
# DATA DOMAIN: frequency
# ------------------------------------
# True Positives: 64.7
# True Negatives: 104
# False Positives: 18.9
# False Negatives: 19
# Total Samples: 206.6
# ------------------------------------
# MEAN:
# Accuracy: 0.8208833
# Precision: 0.7684702999999999
# Sensitivity: 0.8083263
# Specificity: 0.8376027
# TPR: 0.7684702999999999
# FPR: 0.1623974
# F1-Score: 0.8123672
# ------------------------------------
# DEVIATION:
# Accuracy: 0.04006291030878811
# Precision: 0.1012083300386386
# Sensitivity: 0.10049529257935418
# Specificity: 0.05672291071524804
# TPR: 0.1012083300386386
# FPR: 0.0567229791569519
# F1-Score: 0.06627479984850954
# ------------------------------------

# %%
import matplotlib.pyplot as plt

tpr_time, fpr_time, auc_time = final_time_metrics.generate_roc_auc_data()
tpr_freq, fpr_freq, auc_freq = final_frequency_metrics.generate_roc_auc_data()

plt.title('ROC')
plt.plot(fpr_time, tpr_time, 'blue', label = 'Temporal: AUC = %0.2f' % auc_time)
plt.plot(fpr_freq, tpr_freq, 'green', label = 'Frequência: AUC = %0.2f' % auc_freq)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('Taxa de Verdadeiro Positivo')
plt.xlabel('Taxa de Falso Positivo')
plt.show()
