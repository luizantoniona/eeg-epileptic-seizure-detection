# %% [markdown]
# ### Spectrogram

# %%
SIGNAL_TYPE = "spectrogram"

# %%
import Preprocessor.Preprocessor as Preprocessor
X_train, y_train, X_val, y_val, X_test, y_test = Preprocessor.preprocess(SIGNAL_TYPE)
# Out:
# Setting channel info structure...
# Setting channel info structure...
# Setting channel info structure...
# Creating raw.info structure...
# Creating raw.info structure...
# Creating raw.info structure...
# c:\Users\luiza\Desktop\Mestrado\Trabalho\Reader\Reader.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   mne_model = mne.io.read_raw_edf(summary_model.fullpath(),
# c:\Users\luiza\Desktop\Mestrado\Trabalho\Reader\Reader.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   mne_model = mne.io.read_raw_edf(summary_model.fullpath(),
# c:\Users\luiza\Desktop\Mestrado\Trabalho\Reader\Reader.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   mne_model = mne.io.read_raw_edf(summary_model.fullpath(),
# c:\Users\luiza\Desktop\Mestrado\Trabalho\Reader\Reader.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   mne_model = mne.io.read_raw_edf(summary_model.fullpath(),
# c:\Users\luiza\Desktop\Mestrado\Trabalho\Reader\Reader.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   mne_model = mne.io.read_raw_edf(summary_model.fullpath(),
# (2188, 18, 7, 1281)
# (596, 18, 7, 1281)
# (336, 18, 7, 1281)

# %% [markdown]
# ### Convolutional Neural Network

# %%
import Trainer.Trainer as Trainer
Trainer.train(X_train, y_train, X_val, y_val, X_test, y_test, "CNN", SIGNAL_TYPE)
# Out:
# CNN
# spectrogram
# 11/11 [==============================] - 0s 13ms/step
# True Positives: 127
# True Negatives: 136
# False Positives: 41
# False Negatives: 32
# total Samples: 336
# Accuracy: 0.7827380952380952
# Precision: 0.7559523809523809
# Sensitivity: 0.7987421383647799
# Specificity: 0.768361581920904
# TPR: 0.7559523809523809
# FPR: 0.23163841807909605
# F1-Score: 0.7906591390595225

# %% [markdown]
# ### Recurrent Neural Network

# %%
import Trainer.Trainer as Trainer
Trainer.train(X_train, y_train, X_val, y_val, X_test, y_test, "RNN", SIGNAL_TYPE)
# Out:
# RNN
# spectrogram
# 11/11 [==============================] - 1s 32ms/step
# True Positives: 114
# True Negatives: 136
# False Positives: 54
# False Negatives: 32
# total Samples: 336
# Accuracy: 0.7440476190476191
# Precision: 0.6785714285714286
# Sensitivity: 0.7808219178082192
# Specificity: 0.7157894736842105
# TPR: 0.6785714285714286
# FPR: 0.28421052631578947
# F1-Score: 0.7619913373616385

# %% [markdown]
# ### Convolutional Recurrent Neural Network

# %%
import Trainer.Trainer as Trainer
Trainer.train(X_train, y_train, X_val, y_val, X_test, y_test, "CRNN", SIGNAL_TYPE)
# Out:
# CRNN
# spectrogram
# 11/11 [==============================] - 1s 12ms/step
# True Positives: 134
# True Negatives: 126
# False Positives: 34
# False Negatives: 42
# total Samples: 336
# Accuracy: 0.7738095238095238
# Precision: 0.7976190476190477
# Sensitivity: 0.7613636363636364
# Specificity: 0.7875
# TPR: 0.7976190476190477
# FPR: 0.2125
# F1-Score: 0.7675361297144871

# %% [markdown]
# ### Siamese Neural Network

# %%
#TODO: Siamese

# %% [markdown]
# ### Vision Transformer

# %%
#TODO: ViT
